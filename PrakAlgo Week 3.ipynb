# %% [markdown]
# #**Download** **Resources**

# %%
# !pip install wget
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9656 sha256=82bbfc347c0096ee28cb522e7f469702c7055af49c1a9bc1f45578adbe8b0a39
#   Stored in directory: /root/.cache/pip/wheels/8b/f1/7f/5c94f0a7a505ca1c81cd1d9208ae2064675d97582078e6c769
# Successfully built wget
# ...

# %%
# !mkdir -p /resources/data
# !wget -O /resources/data/Example1.txt https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/PY0101EN/labs/example1.txt
# Out:
# --2024-09-06 08:56:58--  https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/PY0101EN/labs/example1.txt
# Resolving s3-api.us-geo.objectstorage.softlayer.net (s3-api.us-geo.objectstorage.softlayer.net)... 67.228.254.196
# Connecting to s3-api.us-geo.objectstorage.softlayer.net (s3-api.us-geo.objectstorage.softlayer.net)|67.228.254.196|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 45 [text/plain]
# Saving to: ‘/resources/data/Example1.txt’
#
# /resources/data/Exa 100%[===================>]      45  --.-KB/s    in 0s
#
# 2024-09-06 08:56:58 (24.4 MB/s) - ‘/resources/data/Example1.txt’ saved [45/45]

# %% [markdown]
# # **Read** **File**

# %%
file=open("/resources/data/Example1.txt","r")

# %%
example1 = "/resources/data/Example1.txt"
file1 = open(example1, "r")

# %%
file1.name
# Out:
# '/resources/data/Example1.txt'

# %%
file1.mode
# Out:
# 'r'

# %%
FileContent = file1.read()
FileContent
# Out:
# ''

# %%
print(FileContent)

# %%
type(FIleContent)
# Out:
# str

# %%
file1.close()

# %% [markdown]
# # **Better Way to Open File**

# %%
with open(example1, "r") as file1:
    FileContent = file1.read()
    print(FileContent)
# Out:
# This is line 1
# This is line 2
# This is line 3

# %%
file1.closed
# Out:
# True

# %%
print(FileContent)
# Out:
# This is line 1
# This is line 2
# This is line 3

# %%
with open(example1, "r") as file1:
    print(file1.read(4))
# Out:
# This

# %%
with open(example1, "r") as file1:
    print(file1.read(4))
    print(file1.read(4))
    print(file1.read(7))
    print(file1.read(15))
# Out:
# This
#  is
# line 1
#
# This is line 2

# %%
with open(example1, "r") as file1:
    print(file1.read(16))
    print(file1.read(5))
    print(file1.read(9))
# Out:
# This is line 1
#
# This
# is line 2

# %%
with open(example1, "r") as file1:
    print("First line: " + file1.readline())
# Out:
# First line: This is line 1

# %%
with open(example1,"r") as file1:
        i = 0;
        for line in file1:
            print("Iteration", str(i), ": ", line)
            i = i + 1;
# Out:
# Iteration 0 :  This is line 1
#
# Iteration 1 :  This is line 2
#
# Iteration 2 :  This is line 3

# %%
with open(example1, "r") as file1:
    FileasList = file1.readlines()

# %%
FileasList[0]
# Out:
# 'This is line 1 \n'

# %%
FileasList[1]
# Out:
# 'This is line 2\n'

# %%
FileasList[2]
# Out:
# 'This is line 3'

# %% [markdown]
# # **Writing Files**

# %%
# !mkdir -p /resources/data

# %%
with open('/resources/data/Example2.txt', 'w') as writefile:
    writefile.write("This is line A")

# %%
with open('/resources/data/Example2.txt', 'r') as testwritefile:
    print(testwritefile.read())
# Out:
# This is line A

# %%
with open('/resources/data/Example2.txt', 'w') as writefile:
    writefile.write("This is line A\n")
    writefile.write("This is line B\n")

# %%
with open('/resources/data/Example2.txt', 'r') as testwritefile:
    print(testwritefile.read())
# Out:
# This is line A
# This is line B

# %%
with open('/resources/data/Example2.txt', 'a') as testwritefile:
    testwritefile.write("This is line C\n")

# %%
with open('/resources/data/Example2.txt', 'r') as testwritefile:
    print(testwritefile.read())
# Out:
# This is line A
# This is line B
# This is line C

# %%
Lines = ["This is line A\n", "This is line B\n", "This is line C\n"]
Lines
# Out:
# ['This is line A\n', 'This is line B\n', 'This is line C\n']

# %%
with open('Example2.txt', 'w') as writefile:
    for line in Lines:
        print(line)
        writefile.write(line)
# Out:
# This is line A
#
# This is line B
#
# This is line C

# %%
with open('Example2.txt', 'r') as testwritefile:
    print(testwritefile.read())
# Out:
# This is line A
# This is line B
# This is line C

# %%
with open('Example2.txt', 'a') as testwritefile:
    testwritefile.write("This is line D\n")

# %%
with open('Example2.txt', 'r') as testwritefile:
    print(testwritefile.read())
# Out:
# This is line A
# This is line B
# This is line C
# This is line D

# %% [markdown]
# # **Copy File**

# %%
with open('Example2.txt','r') as readfile:
    with open('Example3.txt','w') as writefile:
          for line in readfile:
                writefile.write(line)

# %%
with open('Example3.txt','r') as testwritefile:
    print(testwritefile.read())
# Out:
# This is line A
# This is line B
# This is line C
# This is line D

# %% [markdown]
# # **Weekly** **Exercise**

# %% [markdown]
# # Weekly Exercise 1

# %%
# !mkdir -p /resources/data

# %%
with open('/resources/data/Biodata.txt', 'w') as writefile:
    writefile.write("\033[1mBiodata Siswa Untidar\033[0m\n")
    writefile.write("Nama          : Evellyn Liena\n")
    writefile.write("Program Studi : Teknologi Informasi\n")
    writefile.write("NPM           : 2410506015\n")
    writefile.write("Alamat        : Payaman, Secang, Magelang, Jawa Tengah\n")
    writefile.write("Hobi          : Menggambar\n")
    writefile.write("Email         : evellynliena66@gmail.com\n")

# %%
with open('/resources/data/Biodata.txt', 'r') as testwritefile:
    print(testwritefile.read())
# Out:
# Biodata Siswa Untidar
# Nama          : Evellyn Liena
# Program Studi : Teknologi Informasi
# NPM           : 2410506015
# Alamat        : Payaman, Secang, Magelang, Jawa Tengah
# Hobi          : Menggambar
# Email         : evellynliena66@gmail.com

# %%
with open('/resources/data/Biodata.txt', 'r') as testwritefile:
    print(testwritefile.readlines())
# Out:
# ['\x1bBiodata Siswa Untidar\x1b\n', 'Nama          : Evellyn Liena\n', 'Program Studi : Teknologi Informasi\n', 'NPM           : 2410506015\n', 'Alamat        : Payaman, Secang, Magelang, Jawa Tengah\n', 'Hobi          : Menggambar\n', 'Email         : evellynliena66@gmail.com\n']

# %%
Biodata = "/resources/data/Biodata.txt"

# %%
with open(Biodata, 'r') as biodata_file:
    lines = biodata_file.readlines()
    for line in lines:
        if "Nama" in line or "Program Studi" in line or "Email" in line:
            print(line.strip())
# Out:
# Nama          : Evellyn Liena
# Program Studi : Teknologi Informasi
# Email         : evellynliena66@gmail.com

# %%
with open(Biodata, 'r') as biodata_file:
    with open('Biodata_2.txt', 'w') as new_file:
        for line in biodata_file:
            if "Nama" in line or "NPM" in line or "Program Studi" in line or "Alamat" in line:
                new_file.write(line)

# %%
with open('Biodata_2.txt', 'r') as testwritefile:
    print(testwritefile.read())
# Out:
# Nama          : Evellyn Liena
# Program Studi : Teknologi Informasi
# NPM           : 2410506015
# Alamat        : Payaman, Secang, Magelang, Jawa Tengah

# %% [markdown]
# # **Weekly Exercise 2**

# %%
print("Selamat datang di Toko Maju Jaya")
print("Senin, 4 September 2023    13.05")
print()

print("DAFTAR BELANJA:")
item1 = "Sabun"
item2 = "Shampo"
item3 = "Mie instant"
item4 = "Detergen"
harga1 = 10000
harga2 = 15000
harga3 = 5000
harga4 = 17500

total = harga1 + harga2 + harga3 + harga4

print(str(item1) + ' = Rp' + str(harga1))
print(str(item2) + ' = Rp' + str(harga2))
print(str(item3) + ' = Rp' + str(harga3))
print(str(item4) + ' = Rp' + str(harga4))

print()
print("Total = Rp" + str(total))
# Out:
# Selamat datang di Toko Maju Jaya
# Senin, 4 September 2023    13.05
#
# DAFTAR BELANJA:
# Sabun = Rp10000
# Shampo = Rp15000
# Mie instant = Rp5000
# Detergen = Rp17500
#
# Total = Rp47500

# %%
# !mkdir -p /resources/data

# %%
item1 = "Sabun"
item2 = "Shampo"
item3 = "Mie instant"
item4 = "Detergen"
harga1 = 10000
harga2 = 15000
harga3 = 5000
harga4 = 17500

total = harga1 + harga2 + harga3 + harga4

with open('Kuitansi.txt', 'w') as writefile:
    writefile.write("Selamat Datang di Toko Maju Jaya\n")
    writefile.write("\n")
    writefile.write("Kuitansi - 4 September 2023\n")
    writefile.write("\n")
    writefile.write(item1 + " = Rp " + str(harga1) + "\n")
    writefile.write(item2 + " = Rp " + str(harga2) + "\n")
    writefile.write(item3 + " = Rp " + str(harga3) + "\n")
    writefile.write(item4 + " = Rp " + str(harga4) + "\n")
    writefile.write("\n")
    writefile.write("Total Belanja = Rp " + str(total) + "\n")

# %%
Kuitansi = "Kuitansi.txt"
with open(Kuitansi, 'r') as testwritefile:
    print(testwritefile.read())
# Out:
# Selamat Datang di Toko Maju Jaya
#
# Kuitansi - 4 September 2023
#
# Sabun = Rp 10000
# Shampo = Rp 15000
# Mie instant = Rp 5000
# Detergen = Rp 17500
#
# Total Belanja = Rp 47500
